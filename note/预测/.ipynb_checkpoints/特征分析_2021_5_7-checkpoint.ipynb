# %% [markdown]
# ### 卡方检验-前十
#
# #### 汇总表-未做特征选择
#
# | |  column  |  scores |
# |  ----  |  ----  | ----  |
# 37  |  水样便      |  5.894347
# 4   |  双下肢水肿   |  5.378220
# 29  |  行走困难     | 5.365854
# 36  |  里急后重     | 5.365854
# 62  |  大便未解    |  5.365854
# 6   |   黑便       | 3.972386
# 11  |   腹泻       | 3.972386
# 5   |   乏力      |  3.166946
# 3   |   纳差      |  2.076447
# 34  |   口干      |  1.825826
#
# #### 汇总表-特征选择后
#
# | |  column  |  scores |
# |  ----  |  ----  | ----  |
# 1 | 双下肢水肿 | 5.378220
# 8 |  行走困难  |5.365854
# 3 |    黑便  |3.972386
# 2 |    乏力  |3.166946
# 6 |  全身胀痛 | 1.792740
# 0 |  身目尿黄 | 1.708052
# 4 |    腹痛 | 1.031115
# 7 |    口苦 | 0.891336
# 9 |    欲呕 | 0.748119
# 5 |    咳痰 | 0.439252
#
# #### 人工选择特征
#
# | |  column  |  scores |
# |  ----  |  ----  | ----  |
# 3 |     胃痛（主症） | 104.000000
# 0 |  双下肢水肿（伴随）|   34.000000
# 29|  肝功能异常（伴随）|   34.000000
# 27|     厌油（主症）  | 16.103448
# 2 |     恶心（伴随）  | 13.000000
# 26|   身目发黄（伴随） |  10.275862
# 6 |   身目黄染（主症） |   6.500000
# 10|     厌油（伴随）  |  6.500000
# 14|     尿少（伴随）   | 6.500000
# 21|     发热（伴随）   | 6.500000

# %% [markdown]
# #### 根据卡方挑选特征
#
# 胃痛、双下肢水肿、肝功能异常、厌油、身目尿黄、乏力
