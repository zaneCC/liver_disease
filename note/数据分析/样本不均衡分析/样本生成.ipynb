# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs
from sklearn.datasets import make_gaussian_quantiles

# %% [markdown]
# ### 参数解析
# #### 特征
#
# 特征即图形维度
#
# ##### n_features
# ##### n_informative
# ##### n_redundant
# ##### n_repeated
#
# #### flip_y
# 根据分类比例，多数类将增加噪声，增加分类难度
# > flip_y=0.5
# #### class_sep
# 不同类别样本打散程度，值越大，越容易分类，值越小，越难分类
# > class_sep=0.5
#
# #### 不均衡样本的生成
# ##### weights
# > weights=[0.95, 0.05]

# %%
plt.figure(figsize=(8, 8))
plt.subplots_adjust(bottom=.05, top=.9, left=.05, right=.95)

plt.subplot(321)
plt.title("One informative feature, one cluster per class", fontsize='small')

X1, Y1 = make_classification(n_features=2, n_redundant=0, n_informative=2,weights=[0.8, 0.2],
                             n_clusters_per_class=1, class_sep=0.5)

plt.scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1,
            s=25, edgecolor='k')

plt.show()

# %%
import pandas as pd
import numpy as np

import sys
sys.path.append(r'/Users/zhouzhan/Documents/codes/python_code/liver_disease/liver_disease/analysis/imbalance/')
# sys.path.append(r'E:/liver_disease/liver_disease')
import SMOTE, SMOTE_Borderline1, SMOTE_D

# %%
df = pd.DataFrame(data=X1)
df['Y1'] = Y1
data = df.to_numpy()
print(len(data))
# Out:
# 100

# %%
balanced_data_arr1 = SMOTE.SMOTE(data)
print(len(balanced_data_arr1))
# Out:
# 需生成少数类样本个数： 60
# 160

# %%
plt.scatter(balanced_data_arr1[:, 0], balanced_data_arr1[:, 1], marker='o', c=balanced_data_arr1[:,2],
            s=25, edgecolor='k')

plt.show()

# %%
balanced_data_arr2 = SMOTE_Borderline1.Border_SMOTE(data)
print(len(balanced_data_arr2))
# Out:
# 160

# %%
plt.scatter(balanced_data_arr2[:, 0], balanced_data_arr2[:, 1], marker='o', c=balanced_data_arr2[:,2],
            s=25, edgecolor='k')

plt.show()

# %%
balanced_data_arr3 = SMOTE_D.SMOTE_D(data)
print(len(balanced_data_arr3))
# Out:
# 多数类样本数： 80 , 少数类样本数： 20
# 需生成少数类样本个数： 60
# 实际生成样本数： 50.0
# 150

# %%
plt.scatter(balanced_data_arr3[:, 0], balanced_data_arr3[:, 1], marker='o', c=balanced_data_arr3[:,2],
            s=25, edgecolor='k')

plt.show()

# %%
# 设置字体
mpl.rcParams['font.sans-serif'] = [u'simHei']
mpl.rcParams['axes.unicode_minus'] = False

# %%
# plt.figure(figsize=(8, 8))
# plt.subplots_adjust(bottom=.05, top=.9, left=.05, right=.95)

# 原始样本
plt.subplot(221)
plt.title("原始样本")
plt.scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1,
            s=25, edgecolor='k')

# SMOTE 
plt.subplot(222)
plt.title("SMOTE")
plt.scatter(balanced_data_arr1[:, 0], balanced_data_arr1[:, 1], marker='o', c=balanced_data_arr1[:,2],
            s=25, edgecolor='k')

# Borderline-SMOTE
plt.subplot(223)
plt.title("Borderline-SMOTE")
plt.scatter(balanced_data_arr2[:, 0], balanced_data_arr2[:, 1], marker='o', c=balanced_data_arr2[:,2],
            s=25, edgecolor='k')

# SMOTE-D

plt.show()
plt.subplot(224)
plt.title("SMOTE-D")
plt.scatter(balanced_data_arr3[:, 0], balanced_data_arr3[:, 1], marker='o', c=balanced_data_arr3[:,2],
            s=25, edgecolor='k')

# %% [markdown]
# ### 当少数类穿越多数类时，Borderline-SMOTE 不会在被穿越的多数类中插值
